# %%
from sample_graphs import *
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
from functions import *

# %%
G, Gp, A, B = sample_correlated_Erdos_Renyi(20, 0.3, 0.9)
A = A.toarray(); B = B.toarray()
nx.draw(G)

# %%
print(np.linalg.norm(np.array(A - B), ord='fro'))
# Out:
# 5.477225575051661

# %%
G, Gp, A, B = sample_correlated_geometric(n=20, p=0.3, d=3, s=1)
A = A.toarray(); B = B.toarray()
nx.draw(G)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 G, Gp, A, B = sample_correlated_geometric(n=20, p=0.3, d=3, s=1)
#       2 A = A.toarray(); B = B.toarray()
#       3 nx.draw(G)
#
# TypeError: sample_correlated_geometric() got an unexpected keyword argument 's'

# %%
print(np.array(A - B))

# %%
G0 = nx.erdos_renyi_graph(10, 0.2)
f = ihara(G0)
print(f(0.1))
# Out:
# 1.2018106651165283
